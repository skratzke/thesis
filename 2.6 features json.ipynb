# %%
import pandas as pd
import requests
import os 
import ast
import logging
import time
from time import sleep
import json

# %%
# Load data
df_fmc = pd.read_csv("data/df_fmc_final.csv")
df_fmc = df_fmc[['title', 'author', 'fmc_name']]
print(df_fmc.shape)

# # (Data frame to test accuracy)
# df_sample = df_fmc.sample(n=100, random_state=26)
# df_sample = df_sample[:2]
# df_sample
# Out:
# (14645, 3)

# %%
system_prompt = """
    You are a helpful literary assistant. Your job is to search the internet and assess several aspects for books that are provided to you.

    Most of the questions are about a female major character of the book whose name will be provided alongside the book title. 
    For all questions about the female character, consider any occurrence of the trait or behavior at any point in the book, 
    and give a short explanation for your answer. 

    1. What's the gender of the author? (0 = male, 1 = female, 99 = unclear or non-binary) 
    2. In what year was the book published? (numeric) 
    3. (As a list) What is/are the genre(s) of the book? (list of a maximum of 5 genres in the order of their relevance, try to use common genre names, lower case only) 
    4. Is the female character saved by a male character? (0 = no, 1 = yes, 99 = no information) 
    5. Does the female character save a male character? (0 = no, 1 = yes, 99 = no information) 
    6. Is the female character protected by a male character? (0 = no, 1 = yes, 99 = no information) 
    7. Does the female character protect a male character? (0 = no, 1 = yes, 99 = no information) 
    8. Is the female character’s problem solved through help or luck? (0 = no, 1 = yes, 99 = no information) 
    9. Does the female character solve her own problem through skill? (0 = no, 1 = yes, 99 = no information) 
    10. Is the female character victimized/harmed by a male character? (0 = no, 1 = yes, 99 = no information) 
    11. Is the female character a perpetrator or does she harm a male character? (0 = no, 1 = yes, 99 = no information) 
    12. Does the female character follow orders? (0 = no, 1 = yes, 99 = no information) 
    13. Does the female character give orders? (0 = no, 1 = yes, 99 = no information) 
    14. Is the female character physically weak/incapable? (0 = no, 1 = yes, 99 = no information) 
    15. Is the female character physically strong/capable? (0 = no, 1 = yes, 99 = no information) 
    16. Is the female character fearful/scared of taking risks/challenges? (0 = no, 1 = yes, 99 = no information) 
    17. Is the female character brave/likes taking risks/challenges? (0 = no, 1 = yes, 99 = no information) 
    18: Does the female character care for others (e.g., nurses someone, comforts someone, takes care of children or sick)? (0 = no, 1 = yes, 99 = no information)  
    19: Does the female character not engage in caregiving behaviors (e.g., focuses on tasks or goals without providing emotional or physical support to others)? (0 = no, 1 = yes, 99 = no information) 
    20: Is the female character emotionally aware and attuned to others' needs, moods, or the dynamics between people, and tries to maintain harmony? (0 = no, 1 = yes, 99 = no information) 
    21: Does the female character focus more on practical matters or impersonal concerns than others’ emotions or social dynamics? (0 = no, 1 = yes, 99 = no information) 
    22: Does the female character sacrifice her own goals, desires, or needs to prioritize someone else’s wellbeing or to avoid conflict? (0 = no, 1 = yes, 99 = no information)  
    23: Does the female character maintain personal goals and boundaries, even when others express emotional needs or expectations? (0 = no, 1 = yes, 99 = no information) 
    24. Is the female character a homemaker? (0 = no, 1 = yes, 99 = no information)   
    25. Is the female character a breadwinner? (0 = no, 1 = yes, 99 = no information) 
    26. Is the female character admired for her beauty? (0 = no, 1 = yes, 99 = no information) 
    27. Is the female character admired for her intelligence? (0 = no, 1 = yes, 99 = no information) 
    28. Does the female character have a lower rank occupation (e.g., nurse, assistant, maid, …)? (0 = no, 1 = yes, 99 = no information) 
    29. Does the female character have a higher rank occupation (doctor, manager, ruler, …)? (0 = no, 1 = yes, 99 = no information) 

    For example:
    [
    [1, 1], # first question, female author
    [2, 2011], # second question, publication year is 2011
    [3, ["mystery", "romance", "suspense"]], # third question, genres are mystery, romance, suspense
    [4, 1, "Paul saves Anne from drowning."], # fourth question, answer is yes (so 1), short explanation why 
    [5, 0, "Anne doesn't save any male character."], # fifth question, answer is no (so 0), short explanation why 
    [6, 1, "Anne is protected by her male friend."], # sixth question, answer is yes (so 1), short explanation why
    ...
    ]

"""

user_prompt_template = """
    Please answer the questions defined in your system prompt for the book {title} by {author}.
    The female character in question is {fmc_name}.
"""

# %%
json_schema = {
    "type": "object",
    "properties": {
        "author_gender": { "type": "integer", "enum": [0, 1, 99] },  # Q1
        "year": { "type": "integer" },                               # Q2
        "genres": {
            "type": "array",                                   
            "items": { "type": "string" },
            "minItems": 1,
            "maxItems": 5
        },
        # Q4 to Q29 — each with an answer and explanation
        **{
            f"Q{i}": {
                "type": "object",
                "properties": {
                    "answer": { "type": "integer", "enum": [0, 1, 99] },  # 0 = no, 1 = yes, 2 = unknown
                    "explanation": { "type": "string" }
                },
                "required": ["answer", "explanation"]
            } for i in range(4, 30)
        }
    },
    "required": ["gender", "year", "genres"] + [f"Q{i}" for i in range(4, 30)]
}

# %%
# Set up logging for error tracking
logging.basicConfig(filename='features_log_3.log', level=logging.INFO)

# Setting API key and headers
YOUR_API_KEY = os.environ["PERPLEXITY_API_KEY"]

headers = {
    "Authorization": f"Bearer {YOUR_API_KEY}",
    "Content-Type": "application/json"
}

# Endpoint for the API
url = "https://api.perplexity.ai/chat/completions"

# Store responses, citations, and titles + authors for progress
responses = []
citations = []
titles = []
authors = []
fmc_names = []

# %%
# Function to send a request to the API
def send_request(title, author, fmc_name, retries=3):

    user_prompt = user_prompt_template.format(title=title, author=author, fmc_name = fmc_name)

    payload = {
        "model": "sonar",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "max_tokens": 2000,
        "temperature": 0,
        "response_format": {
            "type": "json_schema",
            "json_schema": { "schema": json_schema} },
        "web_search_options": { "search_context_size": "medium" }
        }

    try:
        # Make the request to the API
        response = requests.post(url, json=payload, headers=headers)
        
        # Check if the response is successful
        if response.status_code == 200:
            response_json = response.json()
            answer = response_json.get('choices', [{}])[0].get('message', {}).get('content', 'No answer found')
            citation = response_json.get("citations", [])
            return answer, citation
        else:
            raise Exception(f"API call failed with status code {response.status_code}")
    
    except Exception as e:
        # Log the error and retry if retries left
        logging.error(f"Error with request for {title} by {author}: {str(e)}")
        if retries > 0:
            logging.info(f"Retrying {retries} more times...")
            sleep(60)  # Sleep to avoid hitting rate limits
            return send_request(title, author, fmc_name, retries - 1)
        else:
            logging.error(f"Failed after retries: {title} by {author}")
            return f"Error: {str(e)}", []

# %%
def save_progress():
    if titles:  # Only save if there's something new
        progress_df = pd.DataFrame({
            'title': titles,
            'author': authors,
            'fmc_name': fmc_names,
            'answer': responses,
            'citation': citations
        })

        file_exists = os.path.exists('progress_features.csv')

        if file_exists:
            progress_df.to_csv('progress_features.csv', mode='a', header=False, index=False)
            logging.info(f"Progress appended: {len(titles)} books.")
        else:
            progress_df.to_csv('progress_features.csv', index=False)
            logging.info(f"Progress saved: {len(titles)} books.")

        # Clear the lists so next save only writes new data
        titles.clear()
        authors.clear()
        responses.clear()
        citations.clear()
        fmc_names.clear()

# %%
# Log money
# $57.99 -> 1800 Bücher später bei ................ (didn't work) (200 books = 2.58)
# $55.41 -> 53.38

# Create subsets
# subset_1 = df_fmc[:1800]
# subset_1

# subset_2 = df_fmc[200:400]
# subset_2

subset_3 = df_fmc[400:1600]
subset_3
# Out:
#                                                   title             author  \
# 400                                      Midwinterblood   Sedgwick, Marcus
# 401                        The Rook The Checquy Files 1   O'Malley, Daniel
# 402                                       The Last Nude       Avery, Ellis
# 403                                 The Time in Between      Dueñas, María
# 404                                    Dark Gold Dark 3  Feehan, Christine
# ...                                                 ...                ...
# 1595  The Ladies of Covington Send Their Love Ladies...    Medlicott, Joan
# 1596  From the Heart of Covington Ladies of Covington 3    Medlicott, Joan
# 1597         At Home in Covington Ladies of Covington 5    Medlicott, Joan
# 1598   Two Days After the Wedding Ladies of Covington 6    Medlicott, Joan
# 1599            As Dead As It Gets Bad Girls Dont Die 3     Alender, Katie
#
#                 fmc_name
# 400                Merle
# 401       Myfanwy Thomas
# 402   Tamara de Lempicka
# 403         Sira Quiroga
# 404    Alexandria Houton
# ...                  ...
# 1595      Amelia Declose
# 1596              Hannah
# 1597      Amelia Declose
# 1598              Hannah
# 1599       Alexis Warren
#
# [1200 rows x 3 columns]

# %%
start_time = time.time()

# Run for df_subset_1
for index, row in subset_3.iterrows():
    title = row["title"]
    author = row["author"]
    fmc_name = row["fmc_name"]

    # Send request and handle response
    answer, citation = send_request(title, author, fmc_name)
    
    # Store responses
    responses.append(answer)
    citations.append(citation)
    titles.append(title)
    authors.append(author)
    fmc_names.append(fmc_name)

    # Save progress every 10 books
    if (index + 1) % 20 == 0:
        save_progress()

# Save the final progress
save_progress()

# Log the total execution time
end_time = time.time()
execution_time = end_time - start_time
logging.info(f"Completed 200 book requests in {execution_time:.2f} seconds.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 10
#       7 fmc_name = row["fmc_name"]
#       9 # Send request and handle response
# ---> 10 answer, citation = send_request(title, author, fmc_name)
#      12 # Store responses
#      13 responses.append(answer)
#
# Cell In[6], line 22, in send_request(title, author, fmc_name, retries)
#       6 payload = {
#       7     "model": "sonar",
#       8     "messages": [
#    (...)     17     "web_search_options": { "search_context_size": "medium" }
#      18     }
#      20 try:
#      21     # Make the request to the API
# ---> 22     response = requests.post(url, json=payload, headers=headers)
#      24     # Check if the response is successful
#      25     if response.status_code == 200:
#
# File ~/Desktop/Thesis/thesis/venv/lib/python3.12/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/Desktop/Thesis/thesis/venv/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Desktop/Thesis/thesis/venv/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/Thesis/thesis/venv/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/Thesis/thesis/venv/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Desktop/Thesis/thesis/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Desktop/Thesis/thesis/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Desktop/Thesis/thesis/venv/lib/python3.12/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/anaconda3/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/anaconda3/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/anaconda3/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# $10.04 (*140) -> $9.23 = 0.81 (*140) -> $113
# 20 min (*140) -> 2800 min = 46h

# %%
df_result = pd.read_csv("progress_features.csv")
df_result
# Out:
#                                               title              author  \
# 0          Dirty Little Secrets JJ Graves Mystery 1       Hart, Liliana
# 1   The Tycoons Vacation Baby for the Billionaire 2        Anne, Melody
# 2                               White Girl Problems        Walker, Babe
# 3                                   The Empty House  Pilcher, Rosamunde
# 4                                       The Unicorn       Murdoch, Iris
# ..                                              ...                 ...
# 95                Charmed to Death Ophelia  Abby  2  Damsgaard, Shirley
# 96                                          Dealova    Nuranindya, Dyan
# 97                        The Promise Fallen Star 4   Sorensen, Jessica
# 98                           A Boy of Good Breeding       Toews, Miriam
# 99                                            Boy21      Quick, Matthew
#
#               fmc_name                                             answer  \
# 0          J.J. Graves   {\n"author_gender": 1,\n"year": 2011,\n"genre...
# 1      Trinity Mathews   {\n"author_gender": 1,\n"year": 2011,\n"genre...
# 2          Babe Walker   {\n"author_gender": 99, "year": 2012, "genres...
# 3       Virginia Keile   {\n"author_gender": 1,\n"year": 1973,\n"genre...
# 4   Hannah Crean-Smith   {\n"author_gender": 1,\n"year": 1963,\n"genre...
# ..                 ...                                                ...
# 95      Ophelia Jensen   {\n"author_gender": 1,\n"year": 2006,\n"genre...
# 96               Karra   {\n"author_gender": 1,\n"year": 2005,\n"genre...
# 97         Gemma Lucas  { "author_gender": 1, "year": 2012, "genres": ...
# 98               Knute  { "author_gender": 1, "year": 1998, "genres": ...
# 99          Erin Quinn  { "author_gender": 0, "year": 2012, "genres": ...
#
#                                              citation
# 0   ['https://www.goodreads.com/book/show/49587058...
# 1   ['https://www.goodreads.com/book/show/19561986...
# 2   ['https://www.goodreads.com/book/show/12413949...
# 3   ['https://www.goodreads.com/book/show/1054377'...
# 4   ['https://en.wikipedia.org/wiki/The_Unicorn_(n...
# ..                                                ...
# 95  ['https://www.goodreads.com/book/show/141036.C...
# 96  ['https://en.brilio.net/entertainment/dealova-...
# 97  ['https://goodreads.com/book/show/13615578.The...
# 98  ['https://quillandquire.com/review/a-boy-of-go...
# 99  ['https://www.supersummary.com/boy21/summary/'...
#
# [100 rows x 5 columns]

# %%
for answer in df_result['answer']:
    print(answer)
# Out:
#  {
# "author_gender": 1,
# "year": 2011,
# "genres": ["mystery", "romance", "suspense", "thriller"],
# "Q4": {"answer": 99, "explanation": "No explicit rescue by male characters mentioned in available sources"},
# "Q5": {"answer": 99, "explanation": "No evidence of J.J. saving male characters in described plot points"},
# "Q6": {"answer": 1, "explanation": "Works closely with Detective Jack Lawson, implying professional protection partnership"},
# "Q7": {"answer": 99, "explanation": "No specific examples of protecting male characters in available summaries"},
# "Q8": {"answer": 99, "explanation": "Resolution details unclear from available sources"},
# "Q9": {"answer": 1, "explanation": "As coroner/detective, uses professional skills to investigate murders"},
# "Q10": {"answer": 1, "explanation": "Becomes target in deadly game due to her own secrets"},
# "Q11": {"answer": 0, "explanation": "No indication of harming male characters in described plot"},
# "Q12": {"answer": 0, "explanation": "Takes initiative in investigations as coroner"},
# "Q13": {"answer": 1, "explanation": "Holds authority position requiring directive actions"},
# "Q14": {"answer": 0, "explanation": "No physical incapacity mentioned"},
# "Q15": {"answer": 1, "explanation": "Handles physically demanding coroner duties"},
# "Q16": {"answer": 0, "explanation": "Actively pursues dangerous investigations"},
# "Q17": {"answer": 1, "explanation": "Confronts murderers and personal risks"},
# "Q18": {"answer": 1, "explanation": "As coroner/funeral director, professionally cares for deceased and bereaved"},
# "Q19": {"answer": 0, "explanation": "Engages in caregiving through professional duties"},
# "Q20": {"answer": 99, "explanation": "Emotional attunement not explicitly described"},
# "Q21": {"answer": 1, "explanation": "Focuses on forensic/practical aspects of investigations"},
# "Q22": {"answer": 0, "explanation": "Maintains professional boundaries despite personal relationships"},
# "Q23": {"answer": 1, "explanation": "Prioritizes investigative work over personal comfort"},
# "Q24": {"answer": 0, "explanation": "Professional career-focused, not homemaker"},
# "Q25": {"answer": 1, "explanation": "Runs mortuary business and holds coroner position"},
# "Q26": {"answer": 99, "explanation": "Physical appearance admiration not mentioned"},
# "Q27": {"answer": 1, "explanation": "Admired for medical expertise and investigative skills"},
# "Q28": {"answer": 0, "explanation": "Holds high-status positions (coroner/doctor)"},
# "Q29": {"answer": 1, "explanation": "Coroner/doctor roles constitute higher-rank occupations"}
# }
#  {
# "author_gender": 1,
# "year": 2011,
# "genres": ["romance", "contemporary", "billionaire romance", "drama", "family"],
# "Q4": {"answer": 1, "explanation": "Drew provides financial support and medical care after her pregnancy complications[7]."},
# "Q5": {"answer": 0, "explanation": "No evidence of Trinity saving a male character."},
# "Q6": {"answer": 1, "explanation": "Drew insists on protecting Trinity and their unborn child after discovering the pregnancy[1][6]."},
# "Q7": {"answer": 0, "explanation": "No protective actions toward male characters described."},
# "Q8": {"answer": 1, "explanation": "Drew's intervention resolves her financial struggles and pregnancy-related health crisis[1][7]."},
# "Q9": {"answer": 0, "explanation": "Her pregnancy complications require external medical intervention[7]."},
# "Q10": {"answer": 1, "explanation": "Physically harmed during a mugging while pregnant[7]."},
# "Q11": {"answer": 0, "explanation": "No intentional harm caused to male characters."},
# "Q12": {"answer": 0, "explanation": "Resists Drew's demands regarding marriage and child custody[1][6]."},
# "Q13": {"answer": 0, "explanation": "No significant order-giving behavior described."},
# "Q14": {"answer": 1, "explanation": "Bedridden due to toxemia during pregnancy[7]."},
# "Q15": {"answer": 0, "explanation": "Physical limitations emphasized during health crisis[7]."},
# "Q16": {"answer": 0, "explanation": "Initially takes impulsive risks (vacation fling)[1][3]."},
# "Q17": {"answer": 1, "explanation": "Makes bold decisions including keeping the pregnancy[1][6]."},
# "Q18": {"answer": 1, "explanation": "Prioritizes unborn child's wellbeing despite personal struggles[1][7]."},
# "Q19": {"answer": 0, "explanation": "Focuses on maternal caregiving[1][7]."},
# "Q20": {"answer": 99, "explanation": "No explicit emotional attunement descriptions found."},
# "Q21": {"answer": 0, "explanation": "Emotional conflicts with Drew dominate her focus[1][6]."},
# "Q22": {"answer": 0, "explanation": "Maintains independence until Drew's persistence[1][6]."},
# "Q23": {"answer": 1, "explanation": "Initially refuses Drew's involvement despite health risks[7]."},
# "Q24": {"answer": 0, "explanation": "No traditional homemaker role described."},
# "Q25": {"answer": 99, "explanation": "Occupation details unspecified beyond financial struggles[1][7]."},
# "Q26": {"answer": 1, "explanation": "Repeatedly described as beautiful by Drew[1][6]."},
# "Q27": {"answer": 99, "explanation": "Intelligence not specifically highlighted."},
# "Q28": {"answer": 99, "explanation": "No occupation details provided."},
# "Q29": {"answer": 99, "explanation": "No occupation details provided."}
# }
#  {
# "author_gender": 99, "year": 2012, "genres": ["satire", "humor", "memoir", "fiction", "chick lit"],
# "Q4": {"answer": 0, "explanation": "No male character saves Babe; her rehab journey is self-initiated[2][5][7]."},
# "Q5": {"answer": 0, "explanation": "Babe does not save any male characters; her focus remains self-centered[2][5][7]."},
# "Q6": {"answer": 0, "explanation": "No male protection is mentioned; Babe navigates her privileged world independently[5][7]."},
# "Q7": {"answer": 0, "explanation": "Babe does not protect male characters; her actions prioritize self-interest[2][5]."},
# "Q8": {"answer": 0, "explanation": "Her problems persist despite rehab; no clear resolution through external help or luck[2][5][7]."},
# "Q9": {"answer": 0, "explanation": "Babe lacks self-awareness to solve problems skillfully; her narcissism dominates[2][5][7]."},
# "Q10": {"answer": 0, "explanation": "No evidence of harm by male characters; conflicts stem from her own behavior[2][5]."},
# "Q11": {"answer": 1, "explanation": "Babe harms others through manipulation (e.g., exploiting her gay best friend Roman)[7]."},
# "Q12": {"answer": 0, "explanation": "Babe resists authority (e.g., steals therapist files, rejects rehab guidance)[2][5][7]."},
# "Q13": {"answer": 1, "explanation": "She demands compliance (e.g., orchestrates elaborate schemes for attention)[5][7]."},
# "Q14": {"answer": 0, "explanation": "No physical incapacity noted; her challenges are psychological/behavioral[2][5]."},
# "Q15": {"answer": 99, "explanation": "Physical strength is irrelevant to her character arc[2][5]."},
# "Q16": {"answer": 0, "explanation": "Babe takes risks (e.g., extreme shopping, stalking love interests)[5][7]."},
# "Q17": {"answer": 1, "explanation": "She pursues challenges recklessly (e.g., $246k shopping spree)[2][5][7]."},
# "Q18": {"answer": 0, "explanation": "Babe shows no caregiving; her interactions are transactional[2][5][7]."},
# "Q19": {"answer": 1, "explanation": "She prioritizes self-gratification over others' needs[2][5][7]."},
# "Q20": {"answer": 0, "explanation": "Lacks emotional awareness; narcissism prevents attunement to others[2][5][7]."},
# "Q21": {"answer": 1, "explanation": "Focuses on superficial goals (fashion, status) over emotional concerns[2][5][7]."},
# "Q22": {"answer": 0, "explanation": "Never sacrifices desires; demands others accommodate her[2][5][7]."},
# "Q23": {"answer": 1, "explanation": "Maintains rigid personal goals despite others' needs[2][5][7]."},
# "Q24": {"answer": 0, "explanation": "Not a homemaker; her lifestyle revolves around consumption[2][5][7]."},
# "Q25": {"answer": 99, "explanation": "Wealth source unclear; likely inherited rather than earned[5][7]."},
# "Q26": {"answer": 1, "explanation": "Admired for beauty and style (e.g., designer obsession)[1][5][7]."},
# "Q27": {"answer": 0, "explanation": "Intelligence is not a noted trait; her decisions are often foolish[2][5]."},
# "Q28": {"answer": 0, "explanation": "No traditional occupation; her 'work' involves superficial projects[5][7]."},
# "Q29": {"answer": 0, "explanation": "Holds no high-rank position; fails at ventures like fashion design[5][7]."}
# }
#  {
# "author_gender": 1,
# "year": 1973,
# "genres": ["romance", "family drama", "women's fiction"],
# "Q4": {"answer": 0, "explanation": "No evidence of physical rescue by a male character."},
# "Q5": {"answer": 0, "explanation": "No indication she saves a male character."},
# "Q6": {"answer": 0, "explanation": "Protection by male characters isn't emphasized."},
# "Q7": {"answer": 1, "explanation": "Protects her children by reclaiming them from her mother-in-law."},
# "Q8": {"answer": 1, "explanation": "Reconciliation with Eustace involves mutual effort and circumstance."},
# "Q9": {"answer": 1, "explanation": "Actively asserts independence by leasing a cottage and retrieving her children."},
# "Q10": {"answer": 0, "explanation": "No direct harm by male characters mentioned."},
# "Q11": {"answer": 0, "explanation": "No harmful actions toward male characters."},
# "Q12": {"answer": 1, "explanation": "Initially compliant with societal/family expectations."},
# "Q13": {"answer": 1, "explanation": "Takes charge of her children's care and living situation."},
# "Q14": {"answer": 0, "explanation": "No physical incapacity described."},
# "Q15": {"answer": 99, "explanation": "Physical strength not discussed."},
# "Q16": {"answer": 0, "explanation": "Overcomes fear to challenge her mother-in-law."},
# "Q17": {"answer": 1, "explanation": "Braves social resistance to rebuild her life."},
# "Q18": {"answer": 1, "explanation": "Primary caregiver to her children."},
# "Q19": {"answer": 0, "explanation": "Caregiving is central to her role."},
# "Q20": {"answer": 1, "explanation": "Sensitive to children's needs and relational dynamics."},
# "Q21": {"answer": 0, "explanation": "Prioritizes emotional and familial harmony."},
# "Q22": {"answer": 1, "explanation": "Initially sacrifices autonomy to please others."},
# "Q23": {"answer": 1, "explanation": "Later establishes boundaries with her mother-in-law."},
# "Q24": {"answer": 1, "explanation": "Focuses on creating a home for her children."},
# "Q25": {"answer": 0, "explanation": "No indication of employment or income generation."},
# "Q26": {"answer": 99, "explanation": "Physical appearance not emphasized."},
# "Q27": {"answer": 99, "explanation": "Intelligence not specifically highlighted."},
# "Q28": {"answer": 0, "explanation": "No occupation mentioned."},
# "Q29": {"answer": 0, "explanation": "No high-rank occupation indicated."}
# }
#  {
# "author_gender": 1,
# "year": 1963,
# "genres": ["gothic fiction", "philosophical fiction", "psychological fiction"],
# "Q4": {"answer": 0, "explanation": "Hannah's attempted escape fails, and she ultimately drowns herself without successful male intervention[7]."},
# "Q5": {"answer": 0, "explanation": "No evidence of Hannah saving male characters; her actions primarily concern self-liberation[7]."},
# "Q6": {"answer": 1, "explanation": "Gerald Scottow enforces her imprisonment under Peter's authority, paradoxically 'protecting' her through confinement[1][6]."},
# "Q7": {"answer": 0, "explanation": "Hannah shows no protective actions toward male characters[6][7]."},
# "Q8": {"answer": 0, "explanation": "Her confinement remains unresolved, ending in suicide rather than external resolution[4][7]."},
# "Q9": {"answer": 0, "explanation": "Her escape attempt fails, and she dies without achieving freedom[7]."},
# "Q10": {"answer": 1, "explanation": "Imprisoned for years by husband Peter after their violent confrontation[1][6]."},
# "Q11": {"answer": 1, "explanation": "Attempted to kill Peter by pushing him off a cliff[1][6]."},
# "Q12": {"answer": 1, "explanation": "Complies with confinement rules until her escape attempt[6][7]."},
# "Q13": {"answer": 0, "explanation": "No evidence of Hannah issuing commands to others[6][7]."},
# "Q14": {"answer": 99, "explanation": "Physical capability not explicitly addressed beyond confinement[6][7]."},
# "Q15": {"answer": 99, "explanation": "No textual evidence regarding physical strength[6][7]."},
# "Q16": {"answer": 1, "explanation": "Shows fear of the outside world and remains psychologically trapped[6][7]."},
# "Q17": {"answer": 1, "explanation": "Attempts escape and confronts captors despite risks[7]."},
# "Q18": {"answer": 0, "explanation": "Focused on her own survival rather than caregiving[6][7]."},
# "Q19": {"answer": 1, "explanation": "Prioritizes escape over emotional support for others[7]."},
# "Q20": {"answer": 0, "explanation": "Described as childlike and self-absorbed in her suffering[6][7]."},
# "Q21": {"answer": 1, "explanation": "Focused on practical escape rather than social dynamics[7]."},
# "Q22": {"answer": 0, "explanation": "Seeks personal freedom above others' needs[7]."},
# "Q23": {"answer": 1, "explanation": "Persists in escape attempts despite others' expectations[7]."},
# "Q24": {"answer": 0, "explanation": "As mistress of Gaze Castle, she's not depicted in domestic roles[6]."},
# "Q25": {"answer": 0, "explanation": "No occupational role; maintained as prisoner[6][7]."},
# "Q26": {"answer": 1, "explanation": "Consistently described as beautiful and ethereal[3][4][6]."},
# "Q27": {"answer": 0, "explanation": "Admired for suffering and beauty, not intellectual traits[3][6]."},
# "Q28": {"answer": 0, "explanation": "Holds nominal authority as castle mistress despite imprisonment[6]."},
# "Q29": {"answer": 0, "explanation": "No occupational authority due to captive status[6][7]."}
# }
#  {
# "author_gender": 0,
# "year": 2004,
# "genres": ["fantasy", "adventure", "young adult"],
# "Q4": {"answer": 0, "explanation": "No evidence of Elli being saved by a male character; she escapes slavery independently and becomes a priestess through her own efforts[1][3][5]."},
# "Q5": {"answer": 99, "explanation": "No explicit information about Elli saving a male character, though she collaborates with Tamwyn and Scree to save Avalon[3][5][7]."},
# "Q6": {"answer": 0, "explanation": "Elli's primary protector is her maryth Nuic, a non-gendered pinnacle sprite[2][5]."},
# "Q7": {"answer": 99, "explanation": "No direct evidence of Elli physically protecting male characters, though she contributes to group survival[3][5]."},
# "Q8": {"answer": 0, "explanation": "Elli actively pursues solutions through her priestess role and collaboration with others rather than relying on luck[3][5][7]."},
# "Q9": {"answer": 1, "explanation": "She demonstrates skill in surviving enslavement, becoming a priestess, and aiding Avalon's salvation[1][3][5]."},
# "Q10": {"answer": 1, "explanation": "Implied through her backstory of parents killed in gnome raids and enslavement (though perpetrators' genders unspecified)[1][2][5]."},
# "Q11": {"answer": 0, "explanation": "No evidence of Elli harming male characters[2][5]."},
# "Q12": {"answer": 1, "explanation": "Follows orders as an apprentice priestess early in her journey[1][2]."},
# "Q13": {"answer": 1, "explanation": "Takes leadership in quests to save Avalon[3][5][7]."},
# "Q14": {"answer": 0, "explanation": "Shows physical capability through survival and quest participation[3][5]."},
# "Q15": {"answer": 1, "explanation": "Demonstrates strength through escape from slavery and active role in Avalon's salvation[1][3][5]."},
# "Q16": {"answer": 0, "explanation": "Persists despite traumatic past and dangerous quests[1][3][5]."},
# "Q17": {"answer": 1, "explanation": "Braves multiple risks to help save Avalon[3][5][7]."},
# "Q18": {"answer": 1, "explanation": "Collaborates with others to protect Avalon's wellbeing[3][5][7]."},
# "Q19": {"answer": 0, "explanation": "Actively engages in caregiving through her priestess role[1][3]."},
# "Q20": {"answer": 1, "explanation": "Works to maintain group cohesion during quests[3][5]."},
# "Q21": {"answer": 0, "explanation": "Balances practical goals with emotional awareness[3][5]."},
# "Q22": {"answer": 0, "explanation": "Maintains focus on saving Avalon despite personal risks[3][5][7]."},
# "Q23": {"answer": 1, "explanation": "Pursues Avalon's salvation as primary goal throughout[3][5][7]."},
# "Q24": {"answer": 0, "explanation": "Serves as active priestess and adventurer[1][3]."},
# "Q25": {"answer": 0, "explanation": "No evidence of traditional breadwinning role[1][3]."},
# "Q26": {"answer": 99, "explanation": "Physical appearance not emphasized in available sources[1][2][5]."},
# "Q27": {"answer": 1, "explanation": "Admired for priestess training and problem-solving skills[1][3][5]."},
# "Q28": {"answer": 1, "explanation": "Begins as apprentice priestess (lower rank)[1][2]."},
# "Q29": {"answer": 0, "explanation": "Does not hold ultimate leadership positions in Avalon's hierarchy[1][3]."}
# }
#  {
# "author_gender": 0,
# "year": 2012,
# "genres": ["thriller", "action", "espionage", "military fiction", "suspense"],
# "Q4": { "answer": 1, "explanation": "Ryan Drake's team rescues Maras from imprisonment[1][3][6]." },
# "Q5": { "answer": 99, "explanation": "No explicit information about Maras saving a male character in available sources." },
# "Q6": { "answer": 1, "explanation": "Drake protects Maras while evading pursuers post-rescue[1][3][6]." },
# "Q7": { "answer": 99, "explanation": "No explicit information about Maras protecting a male character." },
# "Q8": { "answer": 1, "explanation": "Maras' initial freedom results from Drake's team intervention[1][3][6]." },
# "Q9": { "answer": 99, "explanation": "No explicit information about Maras independently solving problems through skill." },
# "Q10": { "answer": 1, "explanation": "Maras endured years of brutal imprisonment (implied male captors)[1][3][6]." },
# "Q11": { "answer": 99, "explanation": "No explicit information about Maras harming male characters." },
# "Q12": { "answer": 99, "explanation": "No information about Maras' post-rescue compliance with orders." },
# "Q13": { "answer": 99, "explanation": "No explicit information about Maras giving orders." },
# "Q14": { "answer": 0, "explanation": "Described as a veteran agent, implying physical capability[1][3][7]." },
# "Q15": { "answer": 1, "explanation": "Characterized as a hardened operative surviving imprisonment[1][3][7]." },
# "Q16": { "answer": 0, "explanation": "Maras persists through dangerous situations post-rescue[1][3][6]." },
# "Q17": { "answer": 1, "explanation": "Collaborates with Drake despite extreme risks[1][3][6]." },
# "Q18": { "answer": 99, "explanation": "No explicit caregiving behaviors described." },
# "Q19": { "answer": 1, "explanation": "Focuses on survival and mission objectives[1][3][6]." },
# "Q20": { "answer": 99, "explanation": "No explicit emotional attunement described." },
# "Q21": { "answer": 1, "explanation": "Prioritizes practical survival over emotional concerns[1][3][6]." },
# "Q22": { "answer": 99, "explanation": "No explicit sacrifice of personal goals described." },
# "Q23": { "answer": 1, "explanation": "Maintains survival focus despite external pressures[1][3][6]." },
# "Q24": { "answer": 0, "explanation": "Active field agent, not homemaker[1][3][6]." },
# "Q25": { "answer": 1, "explanation": "Experienced operative in high-stakes profession[1][3][6]." },
# "Q26": { "answer": 99, "explanation": "No physical description emphasizing beauty." },
# "Q27": { "answer": 1, "explanation": "Implied through veteran agent status and survival skills[1][3][7]." },
# "Q28": { "answer": 0, "explanation": "Holds high-risk intelligence role[1][3][6]." },
# "Q29": { "answer": 1, "explanation": "Experienced operative in elite missions[1][3][6]." }
# }
#  {
# "author_gender": 1,
# "year": 2012,
# "genres": ["romance", "contemporary", "new adult", "angst", "drama"],
# "Q4": {"answer": 99, "explanation": "No explicit rescue by male characters mentioned in available sources"},
# "Q5": {"answer": 99, "explanation": "No evidence of Lexi saving male characters in described plot points"},
# "Q6": {"answer": 0, "explanation": "Lexi navigates conflicts independently; no male protection emphasized"},
# "Q7": {"answer": 99, "explanation": "No information about protecting male characters"},
# "Q8": {"answer": 0, "explanation": "Lexi's problems stem from relationship choices rather than external solutions"},
# "Q9": {"answer": 1, "explanation": "Makes independent decisions about relationships and career despite challenges"},
# "Q10": {"answer": 1, "explanation": "Emotionally harmed by Ramsey's betrayal and Jack's commitment issues"},
# "Q11": {"answer": 99, "explanation": "No evidence of intentional harm to male characters"},
# "Q12": {"answer": 0, "explanation": "Resists pressure to attend Jack's wedding before reluctantly agreeing"},
# "Q13": {"answer": 99, "explanation": "No explicit order-giving behavior described"},
# "Q14": {"answer": 99, "explanation": "Physical capability not addressed in available content"},
# "Q15": {"answer": 99, "explanation": "Physical strength not discussed in plot summaries"},
# "Q16": {"answer": 0, "explanation": "Persists through emotional turmoil and relationship challenges"},
# "Q17": {"answer": 1, "explanation": "Takes risks in relationships and career decisions"},
# "Q18": {"answer": 99, "explanation": "Caregiving behaviors not emphasized in described interactions"},
# "Q19": {"answer": 1, "explanation": "Focuses on personal relationships and career over caregiving"},
# "Q20": {"answer": 1, "explanation": "Navigates complex emotional dynamics between multiple partners"},
# "Q21": {"answer": 0, "explanation": "Primarily driven by emotional relationships rather than practical matters"},
# "Q22": {"answer": 1, "explanation": "Initially sacrifices clarity for relationship harmony before asserting boundaries"},
# "Q23": {"answer": 1, "explanation": "Ultimately makes independent life choices despite others' expectations"},
# "Q24": {"answer": 0, "explanation": "Focused on career and relationships rather than domestic role"},
# "Q25": {"answer": 99, "explanation": "Specific career rank details unavailable"},
# "Q26": {"answer": 1, "explanation": "Described as attractive with multiple romantic interests"},
# "Q27": {"answer": 99, "explanation": "Intellectual capabilities not emphasized in plot summaries"},
# "Q28": {"answer": 99, "explanation": "Career specifics not detailed in available sources"},
# "Q29": {"answer": 99, "explanation": "Professional status unclear beyond general career focus"}
# }
#  {
# "author_gender": 1,
# "year": 2005,
# "genres": ["literary fiction", "drama", "family", "romance"],
# "Q4": {"answer": 1, "explanation": "Pierre (father-in-law) provides emotional support and takes Chloé to the countryside to recover[1][6][7]"},
# "Q5": {"answer": 0, "explanation": "No evidence of Chloé saving any male character"},
# "Q6": {"answer": 1, "explanation": "Pierre protects Chloé by removing her from the crisis environment[1][6]"},
# "Q7": {"answer": 0, "explanation": "No protective actions toward males described"},
# "Q8": {"answer": 1, "explanation": "Pierre's intervention helps Chloé gain perspective[6][7]"},
# "Q9": {"answer": 0, "explanation": "Resolution comes through shared experience rather than individual skill"},
# "Q10": {"answer": 1, "explanation": "Abandoned by husband Adrien[1][8]"},
# "Q11": {"answer": 0, "explanation": "No harmful actions toward males described"},
# "Q12": {"answer": 1, "explanation": "Initially follows Pierre's lead to the countryside[1][6]"},
# "Q13": {"answer": 0, "explanation": "No evidence of command-giving behavior"},
# "Q14": {"answer": 99, "explanation": "Physical capability not addressed"},
# "Q15": {"answer": 99, "explanation": "Physical strength not discussed"},
# "Q16": {"answer": 0, "explanation": "Shows willingness to engage in difficult emotional conversations[6][7]"},
# "Q17": {"answer": 1, "explanation": "Confronts marital collapse and rebuilds life[1][8]"},
# "Q18": {"answer": 1, "explanation": "Mother to two daughters[1][8]"},
# "Q19": {"answer": 0, "explanation": "Primary caregiver role evident"},
# "Q20": {"answer": 1, "explanation": "Sensitive to family dynamics and Pierre's emotional state[6][7]"},
# "Q21": {"answer": 0, "explanation": "Emotional processing dominates narrative"},
# "Q22": {"answer": 1, "explanation": "Prioritizes family stability post-abandonment[8]"},
# "Q23": {"answer": 0, "explanation": "Initial crisis leaves little room for boundary-setting"},
# "Q24": {"answer": 1, "explanation": "Family-oriented role implied through motherhood[1][8]"},
# "Q25": {"answer": 99, "explanation": "Occupation unspecified"},
# "Q26": {"answer": 99, "explanation": "Physical appearance not emphasized"},
# "Q27": {"answer": 99, "explanation": "Intellectual capacity not specifically addressed"},
# "Q28": {"answer": 99, "explanation": "No occupational details provided"},
# "Q29": {"answer": 99, "explanation": "No professional role described"}
# }
# { "author_gender": 1, "year": 2012, "genres": ["paranormal romance", "fantasy", "romance"], "Q4": { "answer": 1, "explanation": "Bettina is saved by Trehan Daciano, who competes in a tournament to claim her hand." }, "Q5": { "answer": 0, "explanation": "There is no indication that Bettina saves a male character." }, "Q6": { "answer": 1, "explanation": "Bettina is protected by Trehan Daciano, who fights to possess her." }, "Q7": { "answer": 0, "explanation": "There is no indication that Bettina protects a male character." }, "Q8": { "answer": 1, "explanation": "Bettina's problems are solved through Trehan's help and her own circumstances." }, "Q9": { "answer": 0, "explanation": "Bettina does not solve her problems through her own skill." }, "Q10": { "answer": 1, "explanation": "Bettina is victimized by the Vrekeners." }, "Q11": { "answer": 0, "explanation": "There is no indication that Bettina harms a male character." }, "Q12": { "answer": 1, "explanation": "Bettina follows her guardians' orders." }, "Q13": { "answer": 0, "explanation": "There is no indication that Bettina gives orders." }, "Q14": { "answer": 1, "explanation": "Bettina is physically weak after being attacked." }, "Q15": { "answer": 0, "explanation": "Bettina is not depicted as physically strong." }, "Q16": { "answer": 1, "explanation": "Bettina is fearful and hesitant about the tournament and her future." }, "Q17": { "answer": 0, "explanation": "Bettina is not portrayed as brave or eager to take risks." }, "Q18": { "answer": 0, "explanation": "There is no indication that Bettina engages in caregiving behaviors." }, "Q19": { "answer": 1, "explanation": "Bettina focuses on her own goals and avoiding the tournament." }, "Q20": { "answer": 0, "explanation": "Bettina is not depicted as emotionally aware or focused on maintaining harmony." }, "Q21": { "answer": 1, "explanation": "Bettina focuses on practical matters like avoiding the tournament." }, "Q22": { "answer": 1, "explanation": "Bettina sacrifices her desires to comply with her guardians' wishes." }, "Q23": { "answer": 0, "explanation": "Bettina does not maintain personal goals or boundaries effectively." }, "Q24": { "answer": 0, "explanation": "Bettina is not a homemaker." }, "Q25": { "answer": 0, "explanation": "Bettina is not depicted as a breadwinner." }, "Q26": { "answer": 1, "explanation": "Bettina is admired for her beauty." }, "Q27": { "answer": 0, "explanation": "There is no indication that Bettina is admired for her intelligence." }, "Q28": { "answer": 0, "explanation": "Bettina does not have a lower rank occupation." }, "Q29": { "answer": 0, "explanation": "Bettina does not have a higher rank occupation in the traditional sense, though she is a princess." } }
#  {
# "author_gender": 1,
# "year": 2006,
# "genres": ["fantasy", "adventure", "young adult", "dragons", "fiction"],
# "Q4": {"answer": 0, "explanation": "No direct evidence of Aket-ten being saved by a male character in *Aerie*; she is portrayed as independent and assertive."},
# "Q5": {"answer": 99, "explanation": "No specific instances of Aket-ten saving a male character in *Aerie* are detailed in available sources."},
# "Q6": {"answer": 0, "explanation": "Aket-ten defies authority and acts independently, with no indication of male protection."},
# "Q7": {"answer": 99, "explanation": "No explicit examples of Aket-ten protecting a male character in *Aerie* are provided in the sources."},
# "Q8": {"answer": 0, "explanation": "Aket-ten actively pursues her goals (e.g., advocating for female Jousters) rather than relying on luck or external help."},
# "Q9": {"answer": 1, "explanation": "She uses her animal-speaking abilities and leadership to advance her objectives, including forming an all-female dragon wing."},
# "Q10": {"answer": 0, "explanation": "No evidence of victimization by male characters in *Aerie*; conflicts are primarily ideological."},
# "Q11": {"answer": 0, "explanation": "No instances of Aket-ten harming male characters are mentioned."},
# "Q12": {"answer": 0, "explanation": "She frequently disobeys orders and challenges authority, particularly Kiron’s leadership."},
# "Q13": {"answer": 1, "explanation": "She advocates for and likely commands her proposed all-female dragon wing."},
# "Q14": {"answer": 0, "explanation": "As a Jouster, she is physically capable of handling dragons and combat."},
# "Q15": {"answer": 1, "explanation": "Her role as a dragon rider and leader implies physical and strategic competence."},
# "Q16": {"answer": 0, "explanation": "She demonstrates bravery by pushing for risky initiatives like the female wing."},
# "Q17": {"answer": 1, "explanation": "Her determination to challenge norms highlights her risk-taking nature."},
# "Q18": {"answer": 99, "explanation": "No explicit caregiving behaviors are described in *Aerie*."},
# "Q19": {"answer": 1, "explanation": "She focuses on strategic goals (e.g., female empowerment) rather than caregiving."},
# "Q20": {"answer": 0, "explanation": "Her conflicts with Kiron suggest limited focus on emotional harmony."},
# "Q21": {"answer": 1, "explanation": "She prioritizes practical goals (e.g., military strategy) over interpersonal dynamics."},
# "Q22": {"answer": 0, "explanation": "She persists in her ambitions despite opposition, refusing to sacrifice her goals."},
# "Q23": {"answer": 1, "explanation": "She maintains her objectives, such as establishing a female wing, despite resistance."},
# "Q24": {"answer": 0, "explanation": "She is a military officer and dragon rider, not a homemaker."},
# "Q25": {"answer": 1, "explanation": "As a Jouster, she holds a high-status, income-generating role."},
# "Q26": {"answer": 99, "explanation": "No explicit mentions of her being admired for beauty."},
# "Q27": {"answer": 1, "explanation": "Her intelligence and animal-speaking abilities are central to her role."},
# "Q28": {"answer": 0, "explanation": "She holds a high-ranking position as a Jouster and leader."},
# "Q29": {"answer": 1, "explanation": "As a dragon rider and officer, she occupies a prestigious role."}
# }
#  {
# "author_gender": 1,
# "year": 2021,
# "genres": ["chick lit", "christian fiction", "romance", "contemporary", "women's fiction"],
# "Q4": {"answer": 0, "explanation": "No evidence of male rescue; Lilly's challenges center on career and relationships, resolved through personal growth and friendships[2][5][7]."},
# "Q5": {"answer": 0, "explanation": "No narrative focus on Lilly saving male characters; plot emphasizes her career struggles and romantic life[2][5][7]."},
# "Q6": {"answer": 0, "explanation": "Protection dynamics focus on female friendships (Spa Girls) rather than male protection[2][5][6]."},
# "Q7": {"answer": 0, "explanation": "No evidence of Lilly protecting male characters; her focus remains on personal and professional challenges[2][5][7]."},
# "Q8": {"answer": 1, "explanation": "Spa weekends with friends help her cope, though ultimate resolution involves personal agency[2][5][6]."},
# "Q9": {"answer": 1, "explanation": "Lilly pursues independent fashion design after workplace setbacks, demonstrating professional initiative[2][5][7]."},
# "Q10": {"answer": 1, "explanation": "Boyfriend's infidelity creates emotional harm, though not physical danger[2][5][7]."},
# "Q11": {"answer": 0, "explanation": "No evidence of Lilly harming male characters; conflicts remain professional/emotional[2][5][7]."},
# "Q12": {"answer": 0, "explanation": "Rebels against expectations (e.g., using Stanford MBA for fashion instead of finance)[5][7]."},
# "Q13": {"answer": 1, "explanation": "As a designer and entrepreneur, likely exercises professional authority[2][5][7]."},
# "Q14": {"answer": 0, "explanation": "No physical incapacity noted; focus on emotional/career challenges[2][5][7]."},
# "Q15": {"answer": 99, "explanation": "Physical capability not addressed in available content[2][5][7]."},
# "Q16": {"answer": 0, "explanation": "Pursues fashion career against family expectations, showing risk tolerance[5][7]."},
# "Q17": {"answer": 1, "explanation": "Establishes independent design business after workplace setbacks[5][7]."},
# "Q18": {"answer": 1, "explanation": "Maintains close friendships with Spa Girls, implying emotional support[2][5][6]."},
# "Q19": {"answer": 0, "explanation": "Engages in caregiving through friendship rituals (spa weekends)[2][5][6]."},
# "Q20": {"answer": 1, "explanation": "Spa Girls' friendship emphasizes emotional attunement and group harmony[2][5][6]."},
# "Q21": {"answer": 0, "explanation": "Focuses on relationships and self-image more than impersonal concerns[2][5][7]."},
# "Q22": {"answer": 0, "explanation": "Pursues fashion career despite family pressure to use finance degree[5][7]."},
# "Q23": {"answer": 1, "explanation": "Maintains career goals despite romantic/professional setbacks[2][5][7]."},
# "Q24": {"answer": 0, "explanation": "Career-focused fashion designer, not homemaker[2][5][7]."},
# "Q25": {"answer": 1, "explanation": "Works as professional designer and later entrepreneur[2][5][7]."},
# "Q26": {"answer": 1, "explanation": "Frequent focus on appearance (e.g., 'bad hair' as plot point)[2][5][7]."},
# "Q27": {"answer": 1, "explanation": "Stanford MBA holder working in competitive design field[5][7]."},
# "Q28": {"answer": 0, "explanation": "Holds professional designer position and later entrepreneurship[2][5][7]."},
# "Q29": {"answer": 1, "explanation": "Works under prominent designer Sarah Lang before independent venture[5][7]."}
# }
# { "author_gender": 1, "year": 2005, "genres": ["fantasy", "epic fantasy", "adventure"], "Q4": { "answer": 99, "explanation": "There is no information about Dathne being saved by a male character." }, "Q5": { "answer": 99, "explanation": "There is no information about Dathne saving a male character." }, "Q6": { "answer": 99, "explanation": "There is no information about Dathne being protected by a male character." }, "Q7": { "answer": 99, "explanation": "There is no information about Dathne protecting a male character." }, "Q8": { "answer": 99, "explanation": "There is no information about Dathne's problem being solved through help or luck." }, "Q9": { "answer": 99, "explanation": "There is no information about Dathne solving her own problem through skill." }, "Q10": { "answer": 99, "explanation": "There is no information about Dathne being victimized by a male character." }, "Q11": { "answer": 99, "explanation": "There is no information about Dathne harming a male character." }, "Q12": { "answer": 99, "explanation": "There is no information about Dathne following orders." }, "Q13": { "answer": 99, "explanation": "There is no information about Dathne giving orders." }, "Q14": { "answer": 0, "explanation": "Dathne is described as having visions and performing Olken magic, indicating she is not physically weak." }, "Q15": { "answer": 1, "explanation": "Dathne's ability to perform Olken magic suggests she is physically capable." }, "Q16": { "answer": 0, "explanation": "Dathne is described as acerbic and unflustered, suggesting she is not fearful." }, "Q17": { "answer": 1, "explanation": "Dathne's actions and demeanor suggest she is brave." }, "Q18": { "answer": 99, "explanation": "There is no information about Dathne engaging in caregiving behaviors." }, "Q19": { "answer": 1, "explanation": "Dathne is focused on her goals and the prophecy, indicating she focuses on tasks rather than emotional support." }, "Q20": { "answer": 99, "explanation": "There is no information about Dathne being emotionally aware and maintaining harmony." }, "Q21": { "answer": 1, "explanation": "Dathne is focused on practical matters like the prophecy and her visions." }, "Q22": { "answer": 99, "explanation": "There is no information about Dathne sacrificing her goals for someone else's wellbeing." }, "Q23": { "answer": 1, "explanation": "Dathne maintains her personal goals and boundaries, especially regarding the prophecy." }, "Q24": { "answer": 0, "explanation": "Dathne is a bookshop owner, not a homemaker." }, "Q25": { "answer": 1, "explanation": "As a bookshop owner, Dathne is a breadwinner." }, "Q26": { "answer": 99, "explanation": "There is no information about Dathne being admired for her beauty." }, "Q27": { "answer": 1, "explanation": "Dathne's intelligence and ability to interpret visions suggest she is admired for her intelligence." }, "Q28": { "answer": 0, "explanation": "Dathne's occupation as a bookshop owner is not typically considered lower rank." }, "Q29": { "answer": 0, "explanation": "Dathne's occupation as a bookshop owner is not typically considered higher rank." } }
#  {
# "author_gender": 1,
# "year": 2005,
# "genres": ["mystery", "romance", "suspense", "crime", "science fiction"],
# "Q4": {"answer": 99, "explanation": "No specific information about Eve being saved by a male character in Survivor in Death."},
# "Q5": {"answer": 99, "explanation": "No specific information about Eve saving a male character in this installment."},
# "Q6": {"answer": 1, "explanation": "Roarke often provides protection through security measures and resources."},
# "Q7": {"answer": 1, "explanation": "Eve protects vulnerable individuals (e.g., child witness Nixie in Survivor in Death)."},
# "Q8": {"answer": 0, "explanation": "Eve typically solves cases through investigative skill rather than luck."},
# "Q9": {"answer": 1, "explanation": "Eve resolves cases using police training and deductive abilities."},
# "Q10": {"answer": 99, "explanation": "No specific information about male-perpetrated harm in this book."},
# "Q11": {"answer": 1, "explanation": "Eve regularly apprehends/perpetrates against male criminals."},
# "Q12": {"answer": 0, "explanation": "Eve frequently operates outside strict protocols."},
# "Q13": {"answer": 1, "explanation": "As lieutenant, she commands a investigative team."},
# "Q14": {"answer": 0, "explanation": "Physically capable (5'10" },
# "Q15": {"answer": 1, "explanation": "Trained in combat and pursuit."},
# "Q16": {"answer": 0, "explanation": "Routinely confronts dangerous suspects."},
# "Q17": {"answer": 1, "explanation": "Takes calculated risks during investigations."},
# "Q18": {"answer": 1, "explanation": "Protects victims/witnesses (e.g., Nixie Swisher)."},
# "Q19": {"answer": 0, "explanation": "Balances caregiving with professional duties."},
# "Q20": {"answer": 1, "explanation": "Shows growing emotional awareness through series."},
# "Q21": {"answer": 1, "explanation": "Prioritizes case resolution over emotional processing."},
# "Q22": {"answer": 0, "explanation": "Maintains professional boundaries despite personal costs."},
# "Q23": {"answer": 1, "explanation": "Persists with investigations against opposition."},
# "Q24": {"answer": 0, "explanation": "Career-focused police lieutenant."},
# "Q25": {"answer": 1, "explanation": "Primary income source before marriage to Roarke."},
# "Q26": {"answer": 99, "explanation": "Beauty not a focal trait in professional context."},
# "Q27": {"answer": 1, "explanation": "Admired for investigative brilliance."},
# "Q28": {"answer": 0, "explanation": "Holds high-ranking police position."},
# "Q29": {"answer": 1, "explanation": "NYPSD lieutenant with command authority."}
# }
#  {
# "author_gender": 0,
# "year": 1963,
# "genres": ["thriller", "adventure", "suspense"],
# "Q4": {"answer": 99, "explanation": "No explicit information about Francesca being saved by a male character in available sources."},
# "Q5": {"answer": 99, "explanation": "No explicit information about Francesca saving a male character in available sources."},
# "Q6": {"answer": 99, "explanation": "No explicit information about protection dynamics involving Francesca in available sources."},
# "Q7": {"answer": 99, "explanation": "No explicit information about Francesca protecting others in available sources."},
# "Q8": {"answer": 99, "explanation": "No explicit information about problem-solving methods for Francesca in available sources."},
# "Q9": {"answer": 99, "explanation": "No explicit information about Francesca's problem-solving skills in available sources."},
# "Q10": {"answer": 99, "explanation": "No explicit information about victimization of Francesca in available sources."},
# "Q11": {"answer": 1, "explanation": "Francesca leads a group of former partisans pursuing the treasure, implying potential for conflict[5][6]."},
# "Q12": {"answer": 0, "explanation": "As a leader of partisans, Francesca likely gives orders rather than follows them[5][6]."},
# "Q13": {"answer": 1, "explanation": "Francesca leads a group of former partisans, indicating a command role[5][6]."},
# "Q14": {"answer": 99, "explanation": "No explicit information about physical capabilities."},
# "Q15": {"answer": 99, "explanation": "No explicit information about physical capabilities."},
# "Q16": {"answer": 0, "explanation": "As a partisan leader pursuing dangerous treasure, she likely embraces risks[5][6]."},
# "Q17": {"answer": 1, "explanation": "Her role as a partisan leader suggests bravery and risk-taking[5][6]."},
# "Q18": {"answer": 99, "explanation": "No explicit caregiving behaviors mentioned."},
# "Q19": {"answer": 1, "explanation": "Focuses on treasure recovery rather than caregiving[5][6]."},
# "Q20": {"answer": 99, "explanation": "No explicit information about emotional attunement."},
# "Q21": {"answer": 1, "explanation": "Prioritizes practical goals (treasure recovery) over emotional concerns[5][6]."},
# "Q22": {"answer": 99, "explanation": "No explicit information about sacrifices."},
# "Q23": {"answer": 1, "explanation": "Maintains focus on treasure recovery goals[5][6]."},
# "Q24": {"answer": 0, "explanation": "No indication of homemaker role; active in treasure pursuit[5][6]."},
# "Q25": {"answer": 99, "explanation": "No explicit information about financial role."},
# "Q26": {"answer": 99, "explanation": "No explicit mention of beauty admiration."},
# "Q27": {"answer": 1, "explanation": "Implied intelligence through leadership of partisan group[5][6]."},
# "Q28": {"answer": 0, "explanation": "Holds leadership position, not lower-rank occupation[5][6]."},
# "Q29": {"answer": 1, "explanation": "Commands former partisans, indicating authority[5][6]."}
# }
#  {
# "author_gender": 1,
# "year": 2012,
# "genres": ["young adult", "spy fiction", "mystery", "thriller", "adventure"],
# "Q4": {"answer": 0, "explanation": "Cammie's primary allies are her female friends and mother, with Zach assisting as part of a team effort rather than singularly saving her[1][5][7]."},
# "Q5": {"answer": 99, "explanation": "No explicit mention of Cammie saving a male character; focus remains on collaborative efforts with her peers[5][7]."},
# "Q6": {"answer": 1, "explanation": "Zach and male faculty like Dr. Steve contribute to her protection, though her mother and friends play larger roles[5][7]."},
# "Q7": {"answer": 99, "explanation": "No direct evidence of Cammie protecting a male character; her protective actions are generally team-oriented[5][7]."},
# "Q8": {"answer": 0, "explanation": "Cammie actively retraces her steps and deciphers clues herself, though friends assist in the process[1][5][7]."},
# "Q9": {"answer": 1, "explanation": "She uses spy training and deductive skills to recover memories and evade the Circle[1][5][7]."},
# "Q10": {"answer": 99, "explanation": "The Circle (gender composition unspecified) harms her, but no male-specific victimization is detailed[1][5]."},
# "Q11": {"answer": 99, "explanation": "No explicit instances of Cammie harming a male character[5][7]."},
# "Q12": {"answer": 0, "explanation": "She frequently disobeys orders to pursue her own investigations[5][7]."},
# "Q13": {"answer": 1, "explanation": "Takes leadership in missions, directing friends during operations[5][7]."},
# "Q14": {"answer": 0, "explanation": "Despite injuries, she remains physically capable as a trained operative[1][5]."},
# "Q15": {"answer": 1, "explanation": "Demonstrates combat skills and endurance throughout her missions[1][5]."},
# "Q16": {"answer": 0, "explanation": "Consistently embraces risks to uncover the truth[5][7]."},
# "Q17": {"answer": 1, "explanation": "Undertakes dangerous global missions despite memory loss[1][5]."},
# "Q18": {"answer": 0, "explanation": "Focuses on solving the mystery rather than caregiving[5][7]."},
# "Q19": {"answer": 1, "explanation": "Prioritizes mission objectives over emotional support[5][7]."},
# "Q20": {"answer": 1, "explanation": "Shows awareness of friends' frustrations and works to rebuild trust[5][7]."},
# "Q21": {"answer": 0, "explanation": "Balances emotional reconciliation with practical mission needs[5][7]."},
# "Q22": {"answer": 1, "explanation": "Initially sacrifices safety by leaving school to protect others[5][7]."},
# "Q23": {"answer": 1, "explanation": "Persists in her goals despite others' concerns about her health[5][7]."},
# "Q24": {"answer": 0, "explanation": "As a spy student, homemaking isn't relevant[6]."},
# "Q25": {"answer": 0, "explanation": "Not engaged in income-generating work[6]."},
# "Q26": {"answer": 99, "explanation": "No emphasis on physical appearance; admired for spy skills[1][6]."},
# "Q27": {"answer": 1, "explanation": "Recognized for strategic thinking and problem-solving[1][6]."},
# "Q28": {"answer": 0, "explanation": "Holds high-status role as elite spy trainee[6]."},
# "Q29": {"answer": 1, "explanation": "Operates as a skilled intelligence operative in training[1][6]."}
# }
#  {
# "author_gender": 1,
# "year": 0, "genres": ["crime thriller", "mystery", "psychological thriller", "domestic suspense", "Nordic noir"],
# "Q4": {"answer": 0, "explanation": "No evidence of Erica being saved by a male character; she independently investigates her mother's past."},
# "Q5": {"answer": 0, "explanation": "Erica does not save any male character; her role focuses on uncovering family secrets."},
# "Q6": {"answer": 1, "explanation": "Patrik becomes involved in the murder investigation linked to Erica's inquiries, providing indirect protection."},
# "Q7": {"answer": 0, "explanation": "No evidence of Erica protecting a male character; her focus is on her child and investigation."},
# "Q8": {"answer": 0, "explanation": "Erica solves her problems through personal investigation and confronting her mother's diaries."},
# "Q9": {"answer": 1, "explanation": "She uses her skills as a writer and researcher to uncover wartime secrets."},
# "Q10": {"answer": 99, "explanation": "No explicit mention of harm by a male character in available synopses."},
# "Q11": {"answer": 0, "explanation": "Erica is not portrayed as harming others; she seeks truth about her family."},
# "Q12": {"answer": 0, "explanation": "Erica acts independently, often pursuing leads without official authority."},
# "Q13": {"answer": 1, "explanation": "As an investigator and writer, she directs her own inquiries and collaborates with others."},
# "Q14": {"answer": 0, "explanation": "No indication of physical incapability; her challenges are intellectual/emotional."},
# "Q15": {"answer": 99, "explanation": "Physical strength is not a focus; capabilities are mental/emotional."},
# "Q16": {"answer": 0, "explanation": "She bravely confronts family secrets despite risks to her safety."},
# "Q17": {"answer": 1, "explanation": "Persists in dangerous investigations, showing courage in uncovering truths."},
# "Q18": {"answer": 1, "explanation": "Cares for her daughter Maja and maintains family relationships."},
# "Q19": {"answer": 0, "explanation": "Balances caregiving with investigative work."},
# ...
#  {
# "author_gender": 1,
# "year": 2006,
# "genres": ["mystery", "paranormal", "cozy mystery", "fiction", "supernatural"],
# "Q4": {"answer": 0, "explanation": "Ophelia takes matters into her own hands against the killer without male intervention[2][5][7]."},
# "Q5": {"answer": 99, "explanation": "No specific information about Ophelia saving a male character."},
# "Q6": {"answer": 0, "explanation": "Detective Comacho antagonizes Ophelia rather than protecting her[5][7]."},
# "Q7": {"answer": 99, "explanation": "No explicit information about Ophelia protecting a male character."},
# "Q8": {"answer": 0, "explanation": "Ophelia uses her psychic abilities and witchcraft to confront the killer[1][5][7]."},
# "Q9": {"answer": 1, "explanation": "She solves the mystery through her paranormal skills and determination[1][5][7]."},
# "Q10": {"answer": 1, "explanation": "The killer (implied male) targets Ophelia and harms her friend Brian[1][5][7]."},
# "Q11": {"answer": 0, "explanation": "No evidence of Ophelia harming a male character."},
# "Q12": {"answer": 0, "explanation": "Ophelia defies authority figures like Detective Comacho[5][7]."},
# "Q13": {"answer": 1, "explanation": "She takes charge of the investigation independently[5][7]."},
# "Q14": {"answer": 0, "explanation": "No indications of physical incapability."},
# "Q15": {"answer": 99, "explanation": "Physical strength isn't emphasized in available descriptions."},
# "Q16": {"answer": 0, "explanation": "She confronts her fears about her psychic gifts and the killer[1][7]."},
# "Q17": {"answer": 1, "explanation": "Ophelia risks her safety to solve the murders[5][7]."},
# "Q18": {"answer": 1, "explanation": "Shows concern for her grandmother Abby after the attack[5]."},
# "Q19": {"answer": 0, "explanation": "She balances caregiving with investigative goals[5][7]."},
# "Q20": {"answer": 1, "explanation": "Uses psychic awareness to understand others' motives[1][5]."},
# "Q21": {"answer": 0, "explanation": "Emotional dynamics drive her paranormal insights[1][5]."},
# "Q22": {"answer": 0, "explanation": "Prioritizes solving the mystery over personal safety[5][7]."},
# "Q23": {"answer": 1, "explanation": "Maintains her investigative mission despite others' skepticism[5][7]."},
# "Q24": {"answer": 0, "explanation": "Works as a librarian, not a homemaker[1][2]."},
# "Q25": {"answer": 99, "explanation": "No specific information about being the primary income earner."},
# "Q26": {"answer": 99, "explanation": "Physical appearance isn't emphasized in available descriptions."},
# "Q27": {"answer": 1, "explanation": "Her psychic abilities and investigative skills demonstrate intelligence[1][7]."},
# "Q28": {"answer": 0, "explanation": "Librarian is a professional role, not inherently lower-rank[1][2]."},
# "Q29": {"answer": 0, "explanation": "Librarian isn't classified as a high-rank occupation[1][2]."}
# }
#  {
# "author_gender": 1,
# "year": 2005,
# "genres": ["young adult", "romance", "drama", "coming-of-age", "friendship"],
# "Q4": {"answer": 0, "explanation": "No evidence of Karra being saved by a male character; she navigates challenges independently"},
# "Q5": {"answer": 0, "explanation": "No information about Karra saving male characters"},
# "Q6": {"answer": 1, "explanation": "Karra receives attention and care from her brother Iraz and Ibel, though not explicitly framed as protection"},
# "Q7": {"answer": 0, "explanation": "No evidence of Karra protecting male characters"},
# "Q8": {"answer": 1, "explanation": "Karra's emotional resolution involves support from friends and Ibel's attention after Dira's departure"},
# "Q9": {"answer": 0, "explanation": "Her problems (grief, relationships) resolve through social support rather than individual skill"},
# "Q10": {"answer": 0, "explanation": "No evidence of harm by male characters; Dira's departure is due to illness"},
# "Q11": {"answer": 0, "explanation": "Karra doesn't harm male characters"},
# "Q12": {"answer": 0, "explanation": "Karra is portrayed as independent and tomboyish, not submissive"},
# "Q13": {"answer": 99, "explanation": "No specific examples of order-giving"},
# "Q14": {"answer": 0, "explanation": "Karra is physically capable as a skilled basketball player"},
# "Q15": {"answer": 1, "explanation": "Her basketball talent demonstrates physical capability"},
# "Q16": {"answer": 0, "explanation": "Karra faces challenges directly, including emotional struggles"},
# "Q17": {"answer": 1, "explanation": "Shows resilience in managing relationships and grief"},
# "Q18": {"answer": 99, "explanation": "No explicit caregiving scenes described"},
# "Q19": {"answer": 1, "explanation": "Focuses on personal relationships and basketball rather than caregiving"},
# "Q20": {"answer": 0, "explanation": "Initially ignores Ibel's attention, suggesting limited emotional attunement"},
# "Q21": {"answer": 1, "explanation": "Prioritizes basketball and personal growth over social dynamics"},
# "Q22": {"answer": 0, "explanation": "Maintains self-identity throughout relationship changes"},
# "Q23": {"answer": 1, "explanation": "Preserves her tomboyish identity despite romantic developments"},
# "Q24": {"answer": 0, "explanation": "High school student, not a homemaker"},
# "Q25": {"answer": 0, "explanation": "No occupational role mentioned"},
# "Q26": {"answer": 1, "explanation": "Described as beautiful with long hair, attracts male attention"},
# "Q27": {"answer": 99, "explanation": "Intelligence not specifically highlighted"},
# "Q28": {"answer": 0, "explanation": "No occupation mentioned"},
# "Q29": {"answer": 0, "explanation": "No occupation mentioned"}
# }
# { "author_gender": 1, "year": 2012, "genres": ["urban fantasy", "romance", "mystery", "apocalyptic fiction", "supernatural fiction"], "Q4": {"answer": 0, "explanation": "There is no indication that Gemma is saved by a male character in the book."}, "Q5": {"answer": 0, "explanation": "Gemma does not save Alex; instead, both are destined to die to save the world."}, "Q6": {"answer": 1, "explanation": "Alex and possibly other male characters may protect Gemma, but specific details are not provided."}, "Q7": {"answer": 1, "explanation": "Gemma works to protect Alex and others from the apocalyptic threats."}, "Q8": {"answer": 0, "explanation": "Gemma's problem is not solved through luck or external help; she must sacrifice herself."}, "Q9": {"answer": 1, "explanation": "Gemma takes action to address her problems, though it involves a personal sacrifice."}, "Q10": {"answer": 99, "explanation": "There is no clear indication of Gemma being victimized by a male character."}, "Q11": {"answer": 0, "explanation": "Gemma does not harm male characters intentionally."}, "Q12": {"answer": 0, "explanation": "There is no mention of Gemma following orders."}, "Q13": {"answer": 1, "explanation": "Gemma takes charge of her situation and makes decisions."}, "Q14": {"answer": 0, "explanation": "Gemma is not described as physically weak."}, "Q15": {"answer": 1, "explanation": "Gemma is capable of facing supernatural challenges."}, "Q16": {"answer": 0, "explanation": "Gemma is not fearful of taking risks."}, "Q17": {"answer": 1, "explanation": "Gemma is brave and willing to face challenges."}, "Q18": {"answer": 1, "explanation": "Gemma cares about Alex and others, showing emotional support."}, "Q19": {"answer": 1, "explanation": "Gemma focuses on her goals and tasks, especially saving the world."}, "Q20": {"answer": 1, "explanation": "Gemma is emotionally aware and concerned about others."}, "Q21": {"answer": 1, "explanation": "Gemma focuses on practical matters like saving the world."}, "Q22": {"answer": 1, "explanation": "Gemma sacrifices her own life to save others."}, "Q23": {"answer": 1, "explanation": "Gemma maintains her personal goals despite emotional challenges."}, "Q24": {"answer": 0, "explanation": "Gemma is not a homemaker."}, "Q25": {"answer": 0, "explanation": "Gemma is not described as a breadwinner."}, "Q26": {"answer": 99, "explanation": "There is no mention of Gemma being admired for her beauty."}, "Q27": {"answer": 99, "explanation": "There is no mention of Gemma being admired for her intelligence."}, "Q28": {"answer": 0, "explanation": "Gemma does not have a lower rank occupation."}, "Q29": {"answer": 0, "explanation": "Gemma does not have a higher rank occupation."} }
# { "author_gender": 1, "year": 1998, "genres": ["humor", "fiction", "small-town life"], "Q4": {"answer": 0, "explanation": "There is no indication that Knute is saved by a male character."}, "Q5": {"answer": 0, "explanation": "There is no mention of Knute saving a male character."}, "Q6": {"answer": 0, "explanation": "There is no evidence that Knute is protected by a male character."}, "Q7": {"answer": 0, "explanation": "There is no indication that Knute protects a male character."}, "Q8": {"answer": 1, "explanation": "Knute's life improves as she returns to her hometown and navigates its challenges, suggesting her problems are solved through a combination of help and luck."}, "Q9": {"answer": 0, "explanation": "There is no clear indication that Knute solves her problems solely through her own skill."}, "Q10": {"answer": 0, "explanation": "There is no mention of Knute being victimized by a male character."}, "Q11": {"answer": 0, "explanation": "There is no indication that Knute harms a male character."}, "Q12": {"answer": 0, "explanation": "There is no evidence that Knute follows orders."}, "Q13": {"answer": 0, "explanation": "There is no indication that Knute gives orders."}, "Q14": {"answer": 0, "explanation": "There is no mention of Knute being physically weak or incapable."}, "Q15": {"answer": 0, "explanation": "There is no specific mention of Knute being physically strong or capable."}, "Q16": {"answer": 0, "explanation": "There is no indication that Knute is fearful of taking risks."}, "Q17": {"answer": 0, "explanation": "There is no clear evidence that Knute is brave or likes taking risks."}, "Q18": {"answer": 1, "explanation": "Knute returns home to care for her father, indicating she engages in caregiving behaviors."}, "Q19": {"answer": 0, "explanation": "Knute's focus on caring for her family suggests she does engage in caregiving behaviors."}, "Q20": {"answer": 1, "explanation": "Knute's actions and relationships suggest she is emotionally aware and attuned to others' needs."}, "Q21": {"answer": 0, "explanation": "There is no indication that Knute focuses more on practical matters than others' emotions."}, "Q22": {"answer": 1, "explanation": "Knute returns home to care for her family, suggesting she sacrifices her own goals for others' wellbeing."}, "Q23": {"answer": 0, "explanation": "There is no clear indication that Knute maintains personal goals and boundaries."}, "Q24": {"answer": 0, "explanation": "There is no specific mention of Knute being a homemaker."}, "Q25": {"answer": 1, "explanation": "As a single mother, Knute likely acts as a breadwinner for her daughter."}, "Q26": {"answer": 0, "explanation": "There is no mention of Knute being admired for her beauty."}, "Q27": {"answer": 0, "explanation": "There is no mention of Knute being admired for her intelligence."}, "Q28": {"answer": 0, "explanation": "There is no indication that Knute has a lower rank occupation."}, "Q29": {"answer": 0, "explanation": "There is no indication that Knute has a higher rank occupation."} }
# { "author_gender": 0, "year": 2012, "genres": ["young adult", "coming-of-age", "sports fiction"], "Q4": {"answer": 0, "explanation": "There is no indication that Erin is saved by a male character."}, "Q5": {"answer": 1, "explanation": "Erin saves Finley by defending him from Don Little."}, "Q6": {"answer": 0, "explanation": "There is no indication that Erin is protected by a male character."}, "Q7": {"answer": 1, "explanation": "Erin protects Finley by defending him from Don Little."}, "Q8": {"answer": 99, "explanation": "There is no clear information on how Erin's problems are solved."}, "Q9": {"answer": 0, "explanation": "There is no indication that Erin solves her own problems through skill."}, "Q10": {"answer": 0, "explanation": "There is no indication that Erin is victimized by a male character."}, "Q11": {"answer": 1, "explanation": "Erin harms Don Little by punching him."}, "Q12": {"answer": 99, "explanation": "There is no information on whether Erin follows orders."}, "Q13": {"answer": 99, "explanation": "There is no information on whether Erin gives orders."}, "Q14": {"answer": 0, "explanation": "Erin is not depicted as physically weak."}, "Q15": {"answer": 1, "explanation": "Erin is physically strong and capable, as shown when she defends Finley."}, "Q16": {"answer": 0, "explanation": "Erin is not depicted as fearful of taking risks."}, "Q17": {"answer": 1, "explanation": "Erin is brave and willing to take risks, as seen when she defends Finley."}, "Q18": {"answer": 1, "explanation": "Erin cares for Finley by helping him after he is hurt."}, "Q19": {"answer": 0, "explanation": "Erin does engage in caregiving behaviors."}, "Q20": {"answer": 1, "explanation": "Erin is emotionally aware and supportive, as seen in her interactions with Finley."}, "Q21": {"answer": 0, "explanation": "Erin focuses on emotional support rather than practical matters."}, "Q22": {"answer": 1, "explanation": "Erin sacrifices her presence in Finley's life to protect him."}, "Q23": {"answer": 0, "explanation": "Erin's actions are driven by emotional considerations rather than maintaining personal goals."}, "Q24": {"answer": 0, "explanation": "There is no indication that Erin is a homemaker."}, "Q25": {"answer": 0, "explanation": "There is no indication that Erin is a breadwinner."}, "Q26": {"answer": 99, "explanation": "There is no information on whether Erin is admired for her beauty."}, "Q27": {"answer": 99, "explanation": "There is no information on whether Erin is admired for her intelligence."}, "Q28": {"answer": 0, "explanation": "There is no indication that Erin has a lower rank occupation."}, "Q29": {"answer": 0, "explanation": "There is no indication that Erin has a higher rank occupation."} }

# %%
type(df_result["answer"].iloc[25])
# Out:
# str

# %%
df_result['answer_parsed'] = df_result['answer'].apply(json.loads)
df_answers = pd.json_normalize(df_result['answer_parsed'])
df_answers

# %%
df_final = pd.concat([df_result[['title', 'author', 'fmc_name', 'citation']], df_answers], axis=1)
df_final
# Out:
#                                               title              author  \
# 0          Dirty Little Secrets JJ Graves Mystery 1       Hart, Liliana
# 1   The Tycoons Vacation Baby for the Billionaire 2        Anne, Melody
# 2                               White Girl Problems        Walker, Babe
# 3                                   The Empty House  Pilcher, Rosamunde
# 4                                       The Unicorn       Murdoch, Iris
# ..                                              ...                 ...
# 95                Charmed to Death Ophelia  Abby  2  Damsgaard, Shirley
# 96                                          Dealova    Nuranindya, Dyan
# 97                        The Promise Fallen Star 4   Sorensen, Jessica
# 98                           A Boy of Good Breeding       Toews, Miriam
# 99                                            Boy21      Quick, Matthew
#
#               fmc_name                                           citation  \
# 0          J.J. Graves  ['https://www.goodreads.com/book/show/49587058...
# 1      Trinity Mathews  ['https://www.goodreads.com/book/show/19561986...
# 2          Babe Walker  ['https://www.goodreads.com/book/show/12413949...
# 3       Virginia Keile  ['https://www.goodreads.com/book/show/1054377'...
# 4   Hannah Crean-Smith  ['https://en.wikipedia.org/wiki/The_Unicorn_(n...
# ..                 ...                                                ...
# 95      Ophelia Jensen  ['https://www.goodreads.com/book/show/141036.C...
# 96               Karra  ['https://en.brilio.net/entertainment/dealova-...
# 97         Gemma Lucas  ['https://goodreads.com/book/show/13615578.The...
# 98               Knute  ['https://quillandquire.com/review/a-boy-of-go...
# 99          Erin Quinn  ['https://www.supersummary.com/boy21/summary/'...
#
#     author_gender  year                                             genres  \
# 0               1  2011             [mystery, romance, suspense, thriller]
# 1               1  2011  [romance, contemporary, billionaire romance, d...
# 2              99  2012        [satire, humor, memoir, fiction, chick lit]
# 3               1  1973           [romance, family drama, women's fiction]
# 4               1  1963  [gothic fiction, philosophical fiction, psycho...
# ..            ...   ...                                                ...
# 95              1  2006  [mystery, paranormal, cozy mystery, fiction, s...
# 96              1  2005  [young adult, romance, drama, coming-of-age, f...
# 97              1  2012  [urban fantasy, romance, mystery, apocalyptic ...
# 98              1  1998                  [humor, fiction, small-town life]
# 99              0  2012       [young adult, coming-of-age, sports fiction]
#
#     Q4.answer                                     Q4.explanation  Q5.answer  \
# 0          99  No explicit rescue by male characters mentione...         99
# 1           1  Drew provides financial support and medical ca...          0
# 2           0  No male character saves Babe; her rehab journe...          0
# 3           0  No evidence of physical rescue by a male chara...          0
# 4           0  Hannah's attempted escape fails, and she ultim...          0
# ..        ...                                                ...        ...
# 95          0  Ophelia takes matters into her own hands again...         99
# 96          0  No evidence of Karra being saved by a male cha...          0
# 97          0  There is no indication that Gemma is saved by ...          0
# 98          0  There is no indication that Knute is saved by ...          0
# 99          0  There is no indication that Erin is saved by a...          1
#
#     ... Q25.answer                                    Q25.explanation  \
# 0   ...          1  Runs mortuary business and holds coroner position
# 1   ...         99  Occupation details unspecified beyond financia...
# 2   ...         99  Wealth source unclear; likely inherited rather...
# 3   ...          0  No indication of employment or income generation.
# 4   ...          0  No occupational role; maintained as prisoner[6...
# ..  ...        ...                                                ...
# 95  ...         99  No specific information about being the primar...
# 96  ...          0                     No occupational role mentioned
# 97  ...          0           Gemma is not described as a breadwinner.
# 98  ...          1  As a single mother, Knute likely acts as a bre...
# 99  ...          0  There is no indication that Erin is a breadwin...
#
#    Q26.answer                                    Q26.explanation Q27.answer  \
# 0          99       Physical appearance admiration not mentioned          1
# 1           1   Repeatedly described as beautiful by Drew[1][6].         99
# 2           1  Admired for beauty and style (e.g., designer o...          0
# 3          99                Physical appearance not emphasized.         99
# 4           1  Consistently described as beautiful and ethere...          0
# ..        ...                                                ...        ...
# 95         99  Physical appearance isn't emphasized in availa...          1
# 96          1  Described as beautiful with long hair, attract...         99
# 97         99  There is no mention of Gemma being admired for...         99
# 98          0  There is no mention of Knute being admired for...          0
# 99         99  There is no information on whether Erin is adm...         99
#
#                                       Q27.explanation Q28.answer  \
# 0   Admired for medical expertise and investigativ...          0
# 1          Intelligence not specifically highlighted.         99
# 2   Intelligence is not a noted trait; her decisio...          0
# 3          Intelligence not specifically highlighted.          0
# 4   Admired for suffering and beauty, not intellec...          0
# ..                                                ...        ...
# 95  Her psychic abilities and investigative skills...          0
# 96          Intelligence not specifically highlighted          0
# 97  There is no mention of Gemma being admired for...          0
# 98  There is no mention of Knute being admired for...          0
# 99  There is no information on whether Erin is adm...          0
#
#                                       Q28.explanation Q29.answer  \
# 0        Holds high-status positions (coroner/doctor)          1
# 1                     No occupation details provided.         99
# 2   No traditional occupation; her 'work' involves...          0
# 3                            No occupation mentioned.          0
# 4   Holds nominal authority as castle mistress des...          0
# ..                                                ...        ...
# 95  Librarian is a professional role, not inherent...          0
# 96                            No occupation mentioned          0
# 97       Gemma does not have a lower rank occupation.          0
# 98  There is no indication that Knute has a lower ...          0
# 99  There is no indication that Erin has a lower r...          0
#
#                                       Q29.explanation
# 0   Coroner/doctor roles constitute higher-rank oc...
# 1                     No occupation details provided.
# 2   Holds no high-rank position; fails at ventures...
# 3                  No high-rank occupation indicated.
# 4   No occupational authority due to captive statu...
# ..                                                ...
# 95  Librarian isn't classified as a high-rank occu...
# 96                            No occupation mentioned
# 97      Gemma does not have a higher rank occupation.
# 98  There is no indication that Knute has a higher...
# 99  There is no indication that Erin has a higher ...
#
# [100 rows x 59 columns]

# %%
### Unnest columns 

# Check length of all columns 

# Make all list elements into columns
